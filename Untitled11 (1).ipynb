# %% [markdown]
# 1.What is a random variable in probability theory?

# %% [markdown]
# Answer :- In probability theory, a random variable is a variable that takes on numerical values based on the outcome of a random experiment.

# %% [markdown]
# 2.What are the types of random variables?

# %% [markdown]
# answer :- In probability theory, random variables are mainly classified into two types based on the kind of values they take:
#
# 1.Discrete Random Variable
#
# 2.Continuous Random Variable

# %% [markdown]
# 3.What is the difference between discrete and continuous distributions ?

# %% [markdown]
# Answer :-  Key Differences: Discrete vs Continuous Distributions
#
# | Feature                     | **Discrete Distribution**                                   | **Continuous Distribution**                                                                  |
# | --------------------------- | ----------------------------------------------------------- | -------------------------------------------------------------------------------------------- |
# | **Values**                  | Countable (finite or countably infinite)                    | Uncountable (infinitely many real values in an interval)                                     |
# | **Probability Function**    | **Probability Mass Function (PMF)**<br>$P(X = x)$           | **Probability Density Function (PDF)**<br>$f(x)$, and $P(a \leq X \leq b) = \int_a^b f(x)dx$ |
#                                      |
# | **Cumulative Distribution** | Step function                                               | Continuous curve                                                                             |

# %% [markdown]
# 4.What are probability distribution functions (PDF)?

# %% [markdown]
# answer :- In probability theory, a Probability Distribution Function (PDF) describes how the probabilities are distributed over the possible values of a random variable.

# %% [markdown]
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF) ?

# %% [markdown]
# answer :-
#
#  | Feature                    | **PDF (Probability Density Function)**                | **CDF (Cumulative Distribution Function)**                        |
# | -------------------------- | ----------------------------------------------------- | ----------------------------------------------------------------- |
# | **Meaning**                | Describes **probability density** at a specific value | Describes **cumulative probability** up to a value                |
# | **Notation**               | $f(x)$                                                | $F(x) = P(X \leq x)$                                              |
# | **Use**                    | Tells how likely a value is around a point            | Tells probability that a value is less than or equal to $x$       |
# | **Probability at a point** | Can be positive (discrete) or density (continuous)    | Not defined for a point; gives total probability up to that point |
# | **Range**                  | PDF values ≥ 0; total area = 1                        | CDF values range from 0 to 1                                      |
# | **Shape**                  | Curve (continuous) or bars (discrete)                 | Always a **non-decreasing** curve or step function                |

# %% [markdown]
# 6.What is a discrete uniform distribution?

# %% [markdown]
# answer :- A discrete uniform distribution is a probability distribution where each possible outcome has an equal probability of occurring.

# %% [markdown]
# 7. What are the key properties of a Bernoulli distribution?

# %% [markdown]
# answer :- The Bernoulli distribution is the simplest discrete probability distribution — it models a single trial that results in either success (1) or failure (0).
#
# Only two outcomes: 0 or 1
#
# Used to model binary events (success/failure, yes/no, win/lose)
#
# | Property                  | Value                                                 |
# | ------------------------- | ----------------------------------------------------- |
# | **Support**               | $x \in \{0, 1\}$                                      |
# | **Mean (Expected value)** | $\mu = E[X] = p$                                      |
# | **Variance**              | $\sigma^2 = p(1 - p)$                                 |
# | **Skewness**              | $\frac{1 - 2p}{\sqrt{p(1 - p)}}$                      |
#                       |
# | **Mode**                  | $0$ if $p < 0.5$, $1$ if $p > 0.5$, both if $p = 0.5$ |

# %% [markdown]
# 8.What is the binomial distribution, and how is it used in probability?

# %% [markdown]
# answer :- The binomial distribution tells you the probability of getting a certain number of successes in a fixed number of independent yes/no trials, where the chance of success stays the same each time.
#
# The binomial distribution is used when:
#
# Each trial is independent
#
# Each trial has only two outcomes (success/failure)
#
# The probability of success remains constant
#
# You're interested in the number of successes in
# 𝑛
# n trials

# %% [markdown]
#  9.What is the Poisson distribution and where is it applied ?

# %% [markdown]
# answer :- The Poisson distribution is used to predict how many times an event will happen in a fixed amount of time or space, when
#
#  The events happen randomly,
#
# Independently of each other,
#
# And at a constant average rate.
#
# The Poisson distribution is applied when you're counting the number of times something happens in a fixed interval, like:
#
# 🔹 Real-life examples:
# Number of phone calls received at a call center per hour
#
# Number of emails received in a day
#
# Number of customers arriving at a store in 10 minutes
#
# Number of printing errors per page in a book
#
# Number of accidents at an intersection in a month

# %% [markdown]
# 10.What is a continuous uniform distribution?

# %% [markdown]
# answer :- The continuous uniform distribution is a probability distribution where every value in a given interval is equally likely to occur.

# %% [markdown]
# 11.What are the characteristics of a normal distribution?

# %% [markdown]
# answer :- The normal distribution (also called the Gaussian distribution) is one of the most important and widely used probability distributions in statistics.
#
# | Characteristic                         | Description                                                                                                               |
# | -------------------------------------- | ------------------------------------------------------------------------------------------------------------------------- |
# | **Shape**                              | **Bell-shaped**, symmetric curve                                                                                          |
# | **Mean, Median, Mode**                 | All are **equal** and located at the center                                                                               |
# | **Symmetry**                           | Perfectly **symmetric** around the mean                                                                                   |
# | **Tails**                              | Extend infinitely in both directions, never touch the x-axis                                                              |
# | **Total Area**                         | Area under the curve = **1** (i.e., total probability = 1)                                                                |
# | **Defined by Two Parameters**          | - $\mu$: Mean (center)<br>- $\sigma$: Standard deviation (spread)                                                         |
# | **68-95-99.7 Rule** (Empirical Rule)   | - \~68% of values fall within $\mu \pm 1\sigma$<br>- \~95% within $\mu \pm 2\sigma$<br>- \~99.7% within $\mu \pm 3\sigma$ |
# | **Probability Density Function (PDF)** | $f(x) = \frac{1}{\sqrt{2\pi\sigma^2}} \, e^{-\frac{(x - \mu)^2}{2\sigma^2}}$                                              |

# %% [markdown]
# 12.What is the standard normal distribution, and why is it important?

# %% [markdown]
# answer :- The standard normal distribution is the universal reference for all normal distributions. It helps in:
#
# Comparing values across different normal distributions
#
# Computing probabilities easily
#
# Conducting many statistical tests

# %% [markdown]
# 13.What is the Central Limit Theorem (CLT), and why is it critical in statistics?

# %% [markdown]
# answer :- The Central Limit Theorem states that:
#
# When you take many random samples (of size
# 𝑛
# n) from any population (with a finite mean and variance), the sampling distribution of the sample mean will:
#
# Become approximately normal as
# 𝑛
# n becomes large,
#
# Regardless of the population’s original distribution.
#
#
#
# | Importance                                  | Explanation                                                                                                                        |
# | ------------------------------------------- | ---------------------------------------------------------------------------------------------------------------------------------- |
# | 🎯 **Justifies using normal distribution**  | Even if the population isn’t normal, we can use normal-based methods for inference (like confidence intervals & hypothesis tests). |
# | 📏 **Enables estimation**                   | Helps estimate population parameters using sample data.                                                                            |
# | 📉 **Applies to many statistics**           | Not just sample means — also applies to proportions, totals, and more.                                                             |
# | 📚 **Foundation of inferential statistics** | Most statistical techniques rely on the CLT to make generalizations from samples to populations.                                   |

# %% [markdown]
# 14.How does the Central Limit Theorem relate to the normal distribution?

# %% [markdown]
# answer :-
#
#  | Central Limit Theorem                                                                                                                                               | Normal Distribution                                                                                                            |
# | ------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------ |
# | CLT says: If you take many samples from **any population**, the **distribution of the sample means** becomes **approximately normal** as the sample size increases. | The resulting **distribution of sample means** will **follow a normal distribution**, regardless of the original data's shape. |
#
#
# The Central Limit Theorem is what connects real-world data to the normal distribution, allowing statisticians to make accurate predictions and conclusions using standard techniques.

# %% [markdown]
# 15.What is the application of Z statistics in hypothesis testing?

# %% [markdown]
# answer :- Z-statistics (or Z-scores) are used in hypothesis testing when you want to determine whether a sample mean (or proportion) is significantly different from a known population value, assuming the population is normally distributed or the sample size is large.

# %% [markdown]
# 16.> How do you calculate a Z-score, and what does it represent?

# %% [markdown]
# answer :- A Z-score tells you how far a data point is from the mean, measured in standard deviations.
#
#  Z-Score Formula:
# σ = population standard deviation
#  = X−μ /σ
# ​
#
# Where:
# 𝑋
# X = the data point
#
# 𝜇
# μ = population mean
#
# 𝜎
# σ = population standard deviation
#
# A Z-score of 0 means the value is exactly at the mean.
#
# A positive Z-score means the value is above the mean.
#
# A negative Z-score means the value is below the mean.
#
# The magnitude tells you how many standard deviations away it is.

# %% [markdown]
# 17. What are point estimates and interval estimates in statistics?

# %% [markdown]
# answer :- 1. Point Estimate
# A point estimate is a single best guess of a population parameter based on a sample.
#
# 2. Interval Estimate
# An interval estimate gives a range of values (not just one) that is likely to contain the population parameter, along with a confidence level (like 95%).

# %% [markdown]
# 18. What is the significance of confidence intervals in statistical analysis?

# %% [markdown]
# answer :- Confidence intervals (CIs) are crucial tools in statistics because they provide a range of values that likely contain a population parameter (like mean or proportion), along with a confidence level (like 95%).

# %% [markdown]
# 19.What is the relationship between a Z-score and a confidence interval?

# %% [markdown]
# answer :- Z-scores determine how wide the confidence interval is.
#
# Higher confidence level ⇒ larger Z-score ⇒ wider interval
#
# Z-scores are the backbone of confidence interval calculations when population standard deviation is known.

# %% [markdown]
# 20. How are Z-scores used to compare different distributions?

# %% [markdown]
# answer :- Z-scores allow you to standardize values from different distributions so you can compare them on the same scale — even if the original data has different units, means, or standard deviations.

# %% [markdown]
# 21.What are the assumptions for applying the Central Limit Theorem?

# %% [markdown]
# answer :- The Central Limit Theorem allows us to assume that the sampling distribution of the sample mean is approximately normal, even if the population distribution is not — but only if certain assumptions are met.
#
#
# | Assumption                                            | Description                                                                                                                                                     |
# | ----------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | ✅ **Random Sampling**                                 | Samples must be **randomly selected** from the population.                                                                                                      |
# | ✅ **Independence**                                    | Observations must be **independent** — one outcome doesn't influence another.                                                                                   |
# | ✅ **Finite Mean and Variance**                        | The population must have a **finite** (not infinite) **mean** and **standard deviation**.                                                                       |
# | ✅ **Sufficiently Large Sample Size**                  | - For **non-normal populations**, sample size $n \geq 30$ is generally enough.<br> - If the population is **normal**, smaller samples (even $n < 30$) are fine. |
# | ✅ **Sampling with Replacement (or large population)** | If sampling **without replacement**, the sample should be **less than 10% of the population** to maintain independence.                                         |

# %% [markdown]
# 22.What is the concept of expected value in a probability distribution?

# %% [markdown]
# answer :- The expected value is the long-term average or mean of a random variable. It tells you what value you would expect on average if an experiment were repeated many times.

# %% [markdown]
# 23. How does a probability distribution relate to the expected outcome of a random variable?

# %% [markdown]
# answer :- The probability distribution of a random variable shows all possible outcomes and their associated probabilities.
#
# The expected outcome (expected value) is the weighted average of these outcomes — where the weights are the probabilities.
#
# | Probability Distribution                                  | Expected Outcome                                 |
# | --------------------------------------------------------- | ------------------------------------------------ |
# | Lists **all possible values** and their **probabilities** | Computes the **average** result you'd expect     |
# | Describes the **full behavior** of a random variable      | Summarizes that behavior with a **single value** |

# %% [markdown]
# practicals

# %% [markdown]
# 1.Write a Python program to generate a random variable and display its value.

# %%
import numpy as np


random_variable = np.random.normal(loc=0, scale=1)

# Display the value
print("Generated Random Variable (Normal Distribution):", random_variable)

# %%
print("Generated Random Variable (Normal Distribution):", random_variable)
# Out:
# Generated Random Variable (Normal Distribution): 0.4434423880508066

# %% [markdown]
# 2.Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Parameters for discrete uniform distribution: values from 1 to 6
low = 1
high = 7

# Define the distribution: randint is inclusive of low and high in this usage
x = np.arange(low, high + 1)  # [1, 2, 3, 4, 5, 6]
pmf_values = [1 / (high - low + 1)] * len(x)  # Equal probabilities

# Plot the PMF
plt.figure(figsize=(8, 4))
plt.stem(x, pmf_values, basefmt=" ")
plt.title('PMF of Discrete Uniform Distribution (1 to 7)')
plt.xlabel('Outcome')
plt.ylabel('Probability')
plt.ylim(0, 1)
plt.xticks(x)
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

# %%
def bernoulli_pmf(x, p):

    if x not in [0, 1]:
        return 0  # Only 0 and 1 are valid outcomes
    if not (0 <= p <= 1):
        raise ValueError("Probability p must be between 0 and 1.")
    return p if x == 1 else 1 - p

# Example usage:
print("P(X=1):", bernoulli_pmf(1, 0.7))  # P(success)
print("P(X=0):", bernoulli_pmf(0, 0.7))  # P(failure)
# Out:
# P(X=1): 0.7
# P(X=0): 0.30000000000000004

# %% [markdown]
# 4.Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters
n = 10       # number of trials
p = 0.5      # probability of success
size = 10000 # number of experiments (sample size)

# Simulate binomial outcomes
data = np.random.binomial(n, p, size)

# Plot histogram
plt.figure(figsize=(8, 5))
plt.hist(data, bins=np.arange(n + 2) - 0.5, density=True, edgecolor='black', alpha=0.7, label='Simulated Data')

# Plot theoretical PMF for comparison
x = np.arange(0, n + 1)
pmf = binom.pmf(x, n, p)
plt.plot(x, pmf, 'o-', color='red', label='Theoretical PMF')

# Plot settings
plt.title(f'Binomial Distribution Simulation (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(x)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 5.Create a Poisson distribution and visualize it using Python.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters for the Poisson distribution
lam = 4  # average number of events (λ)

# Range of x values to display
x = np.arange(0, 15)

# Calculate PMF values
pmf = poisson.pmf(x, mu=lam)

# Plot the PMF
plt.figure(figsize=(8, 5))
plt.stem(x, pmf, basefmt=" ")
plt.title(f'Poisson Distribution (λ = {lam})')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete
# uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters of the discrete uniform distribution
low = 1
high = 6

# Discrete outcomes: 1 through 6
x = np.arange(low, high + 1)

# PMF: All outcomes are equally likely
pmf = np.full_like(x, 1 / len(x), dtype=np.float64)

# CDF: Cumulative sum of PMF values
cdf = np.cumsum(pmf)

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(x, cdf, where='post', label='CDF', color='blue', linewidth=2)
plt.scatter(x, cdf, color='red')  # dots at steps
plt.title('CDF of Discrete Uniform Distribution (1 to 6)')
plt.xlabel('Outcome')
plt.ylabel('Cumulative Probability')
plt.xticks(x)
plt.yticks(np.linspace(0, 1, len(x)+1))
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 7. Generate a continuous uniform distribution using NumPy and visualize it

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the continuous uniform distribution
low = 0     # lower bound (a)
high = 10   # upper bound (b)
size = 10000  # number of samples

# Generate random data from the uniform distribution
data = np.random.uniform(low, high, size)

# Plot the histogram
plt.figure(figsize=(8, 5))
plt.hist(data, bins=50, density=True, alpha=0.7, color='skyblue', edgecolor='black', label='Histogram')

# Plot the theoretical PDF (flat line between a and b)
plt.hlines(1 / (high - low), xmin=low, xmax=high, color='red', linestyle='--', linewidth=2, label='Theoretical PDF')

# Labels and formatting
plt.title(f'Continuous Uniform Distribution U({low}, {high})')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 8.Simulate data from a normal distribution and plot its histogram.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mu = 0      # mean
sigma = 1   # standard deviation
size = 10000  # number of samples

# Simulate data from the normal distribution
data = np.random.normal(mu, sigma, size)

# Plot histogram of the data
plt.figure(figsize=(8, 5))
count, bins, ignored = plt.hist(data, bins=50, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Simulated Data')

# Plot the theoretical normal distribution (PDF)
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
pdf = norm.pdf(x, mu, sigma)
plt.plot(x, pdf, 'r--', linewidth=2, label='Theoretical PDF')

# Formatting
plt.title(f'Normal Distribution (μ = {mu}, σ = {sigma})')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 9. Write a Python function to calculate Z-scores from a dataset and plot them.

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    """
    Calculate Z-scores and plot them.

    Parameters:
    data : list or numpy array
        A numerical dataset
    """
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data)

    # Calculate Z-scores
    z_scores = (data - mean) / std

    # Plot Z-scores
    plt.figure(figsize=(10, 5))
    plt.plot(z_scores, marker='o', linestyle='-', color='teal', label='Z-Scores')
    plt.axhline(0, color='black', linewidth=1, linestyle='--')
    plt.axhline(2, color='red', linestyle='--', label='Z = ±2')
    plt.axhline(-2, color='red', linestyle='--')
    plt.title('Z-Scores of Dataset')
    plt.xlabel('Index')
    plt.ylabel('Z-Score')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

    return z_scores

# Example usage:
sample_data = [10, 12, 13, 9, 15, 18, 21, 14, 16, 17]
z = calculate_and_plot_z_scores(sample_data)
print("Z-scores:", z)
# Out:
# Z-scores: [-1.28571429 -0.71428571 -0.42857143 -1.57142857  0.14285714  1.
#   1.85714286 -0.14285714  0.42857143  0.71428571]

# %% [markdown]
# 11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def clt_from_normal_distribution(mu=50, sigma=10, sample_size=30, num_samples=1000):

    np.random.seed(0)  # For reproducibility

    # Step 1: Generate a large normal population (optional for visual check)
    population = np.random.normal(mu, sigma, 100000)

    # Step 2: Draw many samples and compute their means
    sample_means = []
    for _ in range(num_samples):
        sample = np.random.normal(mu, sigma, sample_size)
        sample_means.append(np.mean(sample))

    # Step 3: Plot the population and the sampling distribution of the mean
    plt.figure(figsize=(12, 5))

    # Plot original population
    plt.subplot(1, 2, 1)
    sns.histplot(population, bins=50, kde=True, color='lightgreen')
    plt.title(f'Original Normal Distribution (μ={mu}, σ={sigma})')
    plt.xlabel('Value')
    plt.ylabel('Frequency')

    # Plot distribution of sample means
    plt.subplot(1, 2, 2)
    sns.histplot(sample_means, bins=30, kde=True, color='skyblue')
    plt.title(f'Sampling Distribution of the Mean\nn={sample_size}, Samples={num_samples}')
    plt.xlabel('Sample Mean')
    plt.ylabel('Frequency')

    plt.tight_layout()
    plt.show()

# %%
clt_from_normal_distribution(mu=50, sigma=10, sample_size=30, num_samples=1000)

# %% [markdown]
# 13.Generate random variables and calculate their corresponding probabilities using the binomial distribution.

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n = 10        # number of trials
p = 0.5       # probability of success
size = 10     # number of random values to generate

# Step 1: Generate random variables from binomial distribution
random_vars = np.random.binomial(n, p, size)

# Step 2: Calculate PMF (probability) for each unique value
unique_values = np.unique(random_vars)
probabilities = binom.pmf(unique_values, n, p)

# Display results
print("Random Variables:", random_vars)
print("Unique Values:", unique_values)
print("PMF Probabilities:", probabilities)

# Step 3: Plot the PMF
x = np.arange(0, n + 1)
pmf = binom.pmf(x, n, p)

plt.figure(figsize=(8, 5))
plt.stem(x, pmf, basefmt=" ")
plt.title(f'Binomial Distribution PMF (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Random Variables: [6 4 4 6 6 2 5 5 4 4]
# Unique Values: [2 4 5 6]
# PMF Probabilities: [0.04394531 0.20507812 0.24609375 0.20507812]

# %% [markdown]
# 14.5 Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal
# distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mean, std):
    """
    Calculate the Z-score for a given data point.

    Parameters:
    x : float
        Data point
    mean : float
        Mean of the dataset
    std : float
        Standard deviation of the dataset

    Returns:
    float : Z-score
    """
    return (x - mean) / std

def plot_z_score(z):
    """
    Plot the standard normal distribution and mark the Z-score.

    Parameters:
    z : float
        Z-score to plot
    """
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x, 0, 1)

    plt.figure(figsize=(10, 5))
    plt.plot(x, y, color='blue', label='Standard Normal PDF')

    # Shade the area under the curve up to the Z-score
    x_fill = np.linspace(-4, z, 500)
    y_fill = norm.pdf(x_fill)
    plt.fill_between(x_fill, y_fill, alpha=0.3, color='green', label=f'Area ≤ Z = {z:.2f}')

    plt.axvline(z, color='red', linestyle='--', linewidth=2, label=f'Z = {z:.2f}')
    plt.title('Z-score Visualization on Standard Normal Distribution')
    plt.xlabel('Z')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Example usage
x = 78       # data point
mean = 70    # sample/population mean
std = 5      # sample/population standard deviation

z_score = calculate_z_score(x, mean, std)
print(f"Z-score for x = {x} is: {z_score:.2f}")

# Plot Z-score on the normal distribution
plot_z_score(z_score)
# Out:
# Z-score for x = 78 is: 1.60

# %% [markdown]
# 15.5 Implement hypothesis testing using Z-statistics for a sample dataset.

# %%
import numpy as np
from scipy.stats import norm

def z_test(sample_data, mu_0, alpha=0.05):
    """
    Perform Z-test for population mean.

    Parameters:
    sample_data : list or np.array
        The sample data
    mu_0 : float
        The hypothesized population mean (null hypothesis)
    alpha : float
        Significance level (default is 0.05 for a 95% confidence level)

    Returns:
    z : float
        Computed Z-statistic
    p_value : float
        Two-tailed p-value
    """
    sample_data = np.array(sample_data)
    n = len(sample_data)
    sample_mean = np.mean(sample_data)
    sample_std = np.std(sample_data, ddof=1)  # sample standard deviation

    # Compute Z-statistic
    z = (sample_mean - mu_0) / (sample_std / np.sqrt(n))

    # Compute two-tailed p-value
    p_value = 2 * (1 - norm.cdf(abs(z)))

    print(f"Sample mean: {sample_mean:.2f}")
    print(f"Z-statistic: {z:.3f}")
    print(f"P-value: {p_value:.4f}")

    # Hypothesis decision
    if p_value < alpha:
        print("❌ Reject the null hypothesis (significant difference).")
    else:
        print("✅ Fail to reject the null hypothesis (no significant difference).")

    return z, p_value

# Example sample dataset
data = [102, 98, 101, 100, 99, 97, 103, 104, 99, 100]

# Hypothesized population mean (e.g., from historical data)
mu_0 = 100

# Run the Z-test
z_test(data, mu_0)
# Out:
# Sample mean: 100.30
# Z-statistic: 0.429
# P-value: 0.6682
# ✅ Fail to reject the null hypothesis (no significant difference).
# (np.float64(0.42857142857142455), np.float64(0.6682351417952523))

# %% [markdown]
# 16.Write a Python program to compare the standard deviations of two datasets and visualize the difference.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def compare_standard_deviations(data1, data2):
    """
    Compare the standard deviations of two datasets and visualize the difference.

    Parameters:
    data1, data2 : list or array
        The two datasets to compare
    """
    std1 = np.std(data1, ddof=1)
    std2 = np.std(data2, ddof=1)

    print(f"Standard Deviation of Dataset 1: {std1:.2f}")
    print(f"Standard Deviation of Dataset 2: {std2:.2f}")

    # Combine data for plotting
    combined_data = [data1, data2]

    # Boxplot
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    sns.boxplot(data=combined_data)
    plt.xticks([0, 1], ['Dataset 1', 'Dataset 2'])
    plt.title('Boxplot Comparison')
    plt.ylabel('Values')

    # Histogram
    plt.subplot(1, 2, 2)
    sns.histplot(data1, color='blue', kde=True, label='Dataset 1', alpha=0.5)
    sns.histplot(data2, color='orange', kde=True, label='Dataset 2', alpha=0.5)
    plt.title('Histogram Comparison')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example datasets
data1 = np.random.normal(50, 5, 100)   # mean=50, std=5
data2 = np.random.normal(50, 15, 100)  # same mean, larger std

compare_standard_deviations(data1, data2)
# Out:
# Standard Deviation of Dataset 1: 4.95
# Standard Deviation of Dataset 2: 16.22

# %% [markdown]
# 17.Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution5

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_range_and_iqr(data):
    """
    Calculate the range and interquartile range (IQR) of a dataset.

    Parameters:
    data : list or array
        Numerical dataset

    Returns:
    tuple : (range, IQR)
    """
    data_range = np.max(data) - np.min(data)
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    iqr = q3 - q1

    print(f"Range: {data_range:.2f}")
    print(f"IQR (Interquartile Range): {iqr:.2f}")
    return data_range, iqr

# Step 1: Generate normally distributed data
np.random.seed(0)
data = np.random.normal(loc=100, scale=15, size=200)  # mean=100, std=15

# Step 2: Calculate and print range and IQR
calculate_range_and_iqr(data)

# Step 3: (Optional) Plot boxplot for visualization
plt.figure(figsize=(6, 4))
plt.boxplot(data, vert=False)
plt.title('Boxplot of Normally Distributed Data')
plt.xlabel('Value')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Range: 74.04
# IQR (Interquartile Range): 22.70

# %% [markdown]
# 18. Implement Z-score normalization on a dataset and visualize its transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def z_score_normalize(data):
    """
    Normalize a dataset using Z-score normalization.

    Parameters:
    data : array-like
        Input dataset

    Returns:
    np.ndarray : Z-score normalized dataset
    """
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data, ddof=1)
    z_normalized = (data - mean) / std

    print(f"Original Mean: {mean:.2f}")
    print(f"Original Std Dev: {std:.2f}")
    print(f"Normalized Mean: {np.mean(z_normalized):.2f}")
    print(f"Normalized Std Dev: {np.std(z_normalized, ddof=1):.2f}")

    return z_normalized

# Step 1: Generate a normally distributed dataset
np.random.seed(42)
data = np.random.normal(loc=60, scale=10, size=200)  # mean=60, std=10

# Step 2: Apply Z-score normalization
z_data = z_score_normalize(data)

# Step 3: Visualize original vs normalized data
plt.figure(figsize=(12, 5))

# Histogram Comparison
plt.subplot(1, 2, 1)
sns.histplot(data, kde=True, color='skyblue', label='Original Data')
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.subplot(1, 2, 2)
sns.histplot(z_data, kde=True, color='orange', label='Z-Score Normalized')
plt.title('Z-Score Normalized Distribution')
plt.xlabel('Z-score')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()

# Optional: Boxplot comparison
plt.figure(figsize=(6, 4))
plt.boxplot([data, z_data], labels=["Original", "Z-Normalized"])
plt.title("Boxplot Comparison")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Original Mean: 59.59
# Original Std Dev: 9.31
# Normalized Mean: 0.00
# Normalized Std Dev: 1.00
# /tmp/ipython-input-34-1227551431.py:58: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data, z_data], labels=["Original", "Z-Normalized"])
